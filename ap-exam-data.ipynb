# %%
import pandas as pd
import numpy as np
from pandas import read_excel

# %%
x = read_excel("National_Summary.xlsx",
               index_col=None,
               na_values=['NA'])

# %%
x.head()
# Out:
#     N  \
# 0  HA
# 1   H
# 2  HB
# 3  HC
# 4  H2
#
# ...
